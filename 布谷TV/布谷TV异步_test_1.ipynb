# %%
import requests
import re
from lxml import etree
import threading
from multiprocessing.dummy import Pool
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36 Edg/112.0.1722.34'}

# %%
url_2 = 'https://www.bugutv.net/4kmovie'
response_2 = requests.get(url = url_2,headers = headers).text
tree_2 = etree.HTML(response_2)
divs = tree_2.xpath('//*[@id="main"]/div[2]/div[1]/div/div/div[1]/div')
href_list = []
for div in divs:
    href = div.xpath('./article/div[2]/header/h2/a/@href')   
    href = str(href)
    href = href.replace("['",'').replace("']",'')
    print(href)
    href_list.append(href)

# %%
def get_url():
    base_url = 'https://www.bugutv.net/4kuhd/page/'
    url_list_1 = []
    for i in range(1,2):
        url_temp_1 = base_url + str(i)
        print(url_temp_1)
        url_list_1.append(url_temp_1)
    return url_list_1

# %%
def get_response(url_e):
    response = requests.get(url = url_e,headers = headers)
    response = str(response.text)
    print(response)

# %%
url_list_1 = get_url()
# Out:
# https://www.bugutv.net/4kuhd/page/1

# %%
def get_information(url_e_list):
    for url_e in url_e_list:
        response = requests.get(url = url_e,headers = headers).text
        print(response)
        print(type(response))

        for href in href_list:
            response_3 = requests.get(url = href,headers = headers).text
            print('\n',response_3)
            response_list_1.append(response_3)

# %%
get_response_list()
# Out:
# https://www.bugutv.net/4kuhd/page/1
# ﻿<!doctype html>
# <html lang="zh-CN">
# <head>
# 	<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
# 	<meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1">
# 	<link rel="profile" href="https://gmpg.org/xfn/11">
# 	<title>4K蓝光原盘-布谷TV | 布谷4K电影世界</title>
# <meta name='robots' content='max-image-preview:large' />
# <link rel="alternate" type="application/rss+xml" title="布谷TV | 布谷4K电影世界 &raquo; Feed" href="https://www.bugutv.net/feed" />
# <link rel="alternate" type="application/rss+xml" title="布谷TV | 布谷4K电影世界 &raquo; 评论Feed" href="https://www.bugutv.net/comments/feed" />
# <link href="https://www.bugutv.net/wp-content/uploads/2021/09/favicon.jpg" rel="icon">
# <link rel='stylesheet' id='wp-block-library-css'  href='https://www.bugutv.net/wp-includes/css/dist/block-library/style.min.css?ver=5.7' media='all' />
# ...

# %%
get_information('https://www.bugutv.net/4kuhd/page/1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9740\54488134.py in <module>
# ----> 1 get_information('https://www.bugutv.net/4kuhd/page/1')
#
# ~\AppData\Local\Temp\ipykernel_9740\720358296.py in get_information(url_e_list)
#       1 def get_information(url_e_list):
# ----> 2     print(url_e)
#       3     response = requests.get(url = url_e,headers = headers).text
#       4     print(response)
#       5     print(type(response))
#
# NameError: name 'url_e' is not defined

# %%
        response = etree.HTML(response)
        divs = response.xpath('//*[@id="main"]/div[2]/div[1]/div/div/div[1]/div')
        href_list = []
        for div in divs:
            href = div.xpath('./article/div[2]/header/h2/a/@href')   
            href = str(href)
            href = href.replace("['",'').replace("']",'')
            print(href)
            href_list.append(href)
