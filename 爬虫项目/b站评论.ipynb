# %%
import requests 
import re

# %% [markdown]
# ![%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-04-03%20211645.png](attachment:%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-04-03%20211645.png)<br>
# mdoe取值:
# 3 按热度
# 2和1好像都是按时间倒序，即最新评论，2是明确写了最新，但是1的结果好像没差别
# mode好像只有选3的时候next才有用，不然翻页就是0评论<br>
# 有待测试

# %% [markdown]
# <font size=3>https://www.bilibili.com/video/BV1vk4y1871N/?spm_id_from=333.1007.top_right_bar_window_default_collection.content.click&vd_source=205259626d771a8c4b63b9b3a51918ba </font>

# %%
url = 'https://api.bilibili.com/x/v2/reply/main?csrf=4e574def7a3fa2a6fc6161005963d260&mode=3&next=2&oid=738719462&plat=1&seek_rpid=&type=1'
headers = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36 Edg/111.0.1661.62'}

# %%
response = requests.get(url=url,headers = headers).text
print(response)
# Out:
# {"code":0,"message":"0","ttl":1,"data":{"cursor":{"is_begin":false,"prev":2,"next":3,"is_end":false,"all_count":434,"mode":3,"support_mode":[2,3],"name":"热门评论"},"replies":[{"rpid":157101859936,"oid":738719462,"type":1,"mid":1524342557,"root":0,"parent":0,"dialog":0,"count":0,"rcount":0,"state":0,"fansgrade":0,"attr":0,"ctime":1679311455,"rpid_str":"157101859936","root_str":"0","parent_str":"0","like":6,"action":0,"member":{"mid":"1524342557","uname":"组我必坑kill","sex":"保密","sign":"","avatar":"https://i0.hdslb.com/bfs/face/member/noface.jpg","rank":"10000","face_nft_new":0,"is_senior_member":0,"senior":{},"level_info":{"current_level":3,"current_min":0,"current_exp":0,"next_exp":0},"pendant":{"pid":0,"name":"","image":"","expire":0,"image_enhance":"","image_enhance_frame":""},"nameplate":{"nid":0,"name":"","image":"","image_small":"","level":"","condition":""},"official_verify":{"type":-1,"desc":""},"vip":{"vipType":0,"vipDueDate":0,"dueRemark":"","accessStatus":0,"vipStatus":0,"vipStat
# ...

# %%
Findname = re.compile(r'"uname":"(.*?)"')
username = re.findall(Findname,response)
FindTittle = re.compile(r'"content":{"message":"(.*?)"')
tittle_list = re.findall(FindTittle,response)
tittle_1 = str(tittle_list)

for tittle,name in zip(tittle_list,username):
    print(name,":",tittle,"\n")
# Out:
# 陈一夏喂 : 各位 我想说您一两万的相机都买了 完全可以用它去记录生活 去拍喜欢的照片 去自媒体平台上分享自己的作品，想约女生拍照也可以大方一点真诚一点[tv_微笑][tv_微笑][tv_微笑] \n真的没必要 把自己的姿态放的那么低 让自己看起来那么屌丝 想加女生vx的话就直接问呗 完全没必要心里搞那么多小九九，自己贬低自己的价值 \n这个女生的vx我加了 人家还请我喝奶茶 拍照的时候我还是四五个朋友都在旁边 我对象也很认可我 谢谢🙏
#
# 陈一夏喂 : 还有 我拍的糖不糖水不重要 我又不是摄影系的研究生 我又不是普利策的记者 相机是自己花钱买的 想怎么拍就怎么拍 大家完全不用管别人怎么说[tv_调侃][tv_调侃][tv_调侃]
#
# 与光oO : 回复 @陈一夏喂 :我就要说你 咋滴 你拍得很好[doge]
#
# 陈一夏喂 : 你们尽管叫她老婆，她应一声，算我绿
#
# 叫我小包就行 : 老婆
#
# 陈一夏喂 : 回复 @陈一夏喂 :唉[doge]
#
# 恶狼与羔羊同行 : [惊讶]
#
# 陈一夏喂 : 第一张那么好看的云不拍，拍妹子?[doge][doge]
#
# 玛婷嗒 : 尼康行为
#
# Rocket丶鹏 : 拿着尼康说话就是理直气壮[歪嘴]
#
# 岸辺露伴一动不动丶 : 回复 @逆天易知天难 :不不不，我是索尼动感常在[嗑瓜子]
#
# 白夜摄影师 : 用她的相机拍就加不了好友……啊不是 就不能发她照片了[doge]
#
# Rocket丶鹏 : 不谢
#
# 白夜摄影师 : 这装扮，活力满满，上哪领[滑稽]
#
# Leo又饿了 : 忘加狗头了[doge]
#
# 暗云IV : 昨天在江边逛了逛，回去的时候看到有个小姐姐在拍江景，我趁机偷拍了一下，然后立马跑了[doge][doge]
#
# 根本不想起床 : 你这叫偷窥，不叫拍摄[doge]
#
# 暗云IV : 我有点不明白社恐是什么意思了[doge]
#
# 是块好材料 : 社交恐怖分子
#
# b站所有人的唯一真神 : 回复 @陈一夏喂 :我看凳子挺好看 想搜同款 一搜600块[支持][跪了]
#
# 俊綦 : 凳子是张空照片，并不是凳子有什么意义，而是我们解读的时候想赋予它什么意义
#
# 陈一夏喂 : 我感觉我这张也挺好看,用手机拍的
#
# 花京又惊 : 好看
#
# ...
